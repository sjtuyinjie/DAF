# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
with open("../dump_baseline_VAE.pkl", "rb") as f:
    data = pickle.load(f)

# %%
print(np.array(data[0]).shape)
print(np.array(data[1]).shape)
# Out:
# (50, 1000, 1, 2)
# (50, 1, 1, 2)

# %%
distribution = np.array(data[0])
correct = np.array(data[1])

# %%
norm_01 = ((distribution-(-4))/8*128).astype(np.int)
print(norm_01.shape)
# Out:
# (50, 1000, 1, 2)
# /tmp/ipykernel_158636/4206902928.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   norm_01 = ((distribution-(-4))/8*128).astype(np.int)

# %%
for i in range(50):
    cur = norm_01[i]
    arr = np.zeros((128,128))
    for y in range(1000):
        arr[-norm_01[i][y,0,0],-norm_01[i][y,0,1]]+=1.0
    plt.imshow(arr)
    plt.show()
#     assert False

# %%
new_pos = np.mean(distribution, axis=(1,2))
print(new_pos.shape, correct[:,0,0].shape)
diff = np.linalg.norm(new_pos-correct[:,0,0], axis=1)
print(diff.shape)
print(np.mean(diff))
# Out:
# (50, 2) (50, 2)
# (50,)
# 2.6923172

# %%
new_pos
# Out:
# array([[ 28.11 ,  70.895],
#        [ 23.263,  68.904],
#        [ 93.638,  73.661],
#        [ 22.667,  69.284],
#        [ 28.423,  68.957],
#        [ 32.534,  78.224],
#        [ 39.366,  65.725],
#        [ 23.063,  68.812],
#        [ 88.083,  71.993],
#        [ 66.527,  58.37 ],
#        [ 96.721,  68.84 ],
#        [ 22.474,  68.876],
#        [ 63.066,  55.305],
#        [ 85.203,  73.011],
#        [ 30.534,  68.369],
#        [ 24.556,  70.037],
#        [ 36.488,  66.377],
#        [ 41.315,  65.143],
#        [ 89.877,  64.752],
#        [ 44.434,  62.906],
#        [ 31.36 ,  67.662],
#        [ 54.838,  58.067],
#        [ 53.882,  60.535],
#        [ 21.154,  69.35 ],
#        [ 38.817,  65.519],
#        [ 21.543,  69.414],
#        [ 51.429,  59.111],
#        [ 41.362,  65.093],
#        [ 62.817,  57.138],
#        [ 23.956,  69.832],
#        [104.662,  67.952],
#        [ 26.696,  71.586],
#        [ 24.861,  69.296],
#        [ 33.573,  67.656],
# ...
